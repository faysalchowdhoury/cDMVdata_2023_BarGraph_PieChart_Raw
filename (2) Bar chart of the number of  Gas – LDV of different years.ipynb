# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/9aa5b4c5-252c-4d68-b1be-ffe19a2f1d26/download/vehicle-fuel-type-count-by-zip-code.csv')

# Count the occurrences of each model year
model_year_counts = df['Model Year'].value_counts().sort_index()

# Create a bar plot
plt.figure(figsize=(12, 6))
model_year_counts.plot(kind='bar')
plt.xlabel('Model Year')
plt.ylabel('Count')
plt.title('Vehicle Model Year Distribution')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\schowdho\AppData\Local\Temp\ipykernel_5552\3426959494.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/9aa5b4c5-252c-4d68-b1be-ffe19a2f1d26/download/vehicle-fuel-type-count-by-zip-code.csv')

# %%
df['Model Year'].unique()
# Out:
# array(['2010', '2012', '2013', '<2009', '2008', '2009', '2011', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'], dtype=object)

# %%
# group the dataset by the 'Make' column and count the number of rows in each group
vehicles_by_Fuel = df.groupby('Model Year').count()['Vehicles'].sort_values(ascending=False)

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_make)
    
    # calculate the total number of vehicles
df['Vehicles'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 # print the results
#       5 with pd.option_context('display.max_rows', None, 'display.max_columns', None):
# ----> 6     print(vehicles_by_make)
#       8     # calculate the total number of vehicles
#       9 df['Vehicles'].count()
#
# NameError: name 'vehicles_by_make' is not defined

# %%
# group the dataset by the 'Make' column and count the number of rows in each group
vehicles_by_Fuel_Duty2023 = df.groupby(['Fuel', 'Duty']).sum()['Vehicles'].sort_values(ascending=False)

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty2023)
    
    # calculate the total number of vehicles
df['Vehicles'].sum()

# %%
excel_file=pd.ExcelWriter("vehicles_by_Fuel_Duty2023.xlsx")
vehicles_by_Fuel_Duty2023.to_excel(excel_file)
excel_file.save()

# %%
fuel_counts = df.groupby('Model Year')['Vehicles'].sum().reset_index()

# %%
plt.bar(fuel_counts['Model Year'], fuel_counts['Vehicles'])
plt.xticks(rotation=90)
plt.xlabel('Fuel Type')
plt.ylabel('Number of Vehicles')
plt.title('Distribution of Vehicles by Fuel Type')
plt.show()

# %%
# group the dataset by the 'Make' column and count the number of rows in each group
vehicles_by_Fuel_Duty2023 = df.groupby(['Fuel', 'Duty']).sum()['Vehicles'].sort_values(ascending=False)

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty2023)
    
    # calculate the total number of vehicles
df['Vehicles'].sum()

# %%
excel_file=pd.ExcelWriter("vehicles_by_Fuel_Duty2023.xlsx")
vehicles_by_Fuel_Duty2023.to_excel(excel_file)
excel_file.save()

# %%
# Filter the DataFrame to include only rows with 'Model Year' equal to 2018
df_2018 = df[df['Model Year'] == 2018]

# group the dataset by the 'Make' column and count the number of rows in each group
vehicles_by_Fuel_Duty = df.groupby([ 'Duty','Fuel', 'Model Year']).count()['Vehicles'].sort_values(ascending=False)

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_Fuel_Duty)
    
    # calculate the total number of vehicles
df['Vehicles'].sum()
